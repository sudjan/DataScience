# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("C:/Users/sudja/Downloads/list-of-airports-in-india-hxl-tags-1.csv")
data = data.drop(0)
data
# Out:
#          id    ident           type  \
# 1     26555     VIDP  large_airport
# 2     26434     VABB  large_airport
# 3     35145     VOBL  large_airport
# 4     26618     VOMM  large_airport
# 5     26444     VAGO  large_airport
# ..      ...      ...            ...
# 340   46625  IN-0062  small_airport
# 341   46640  IN-0064  small_airport
# 342   46561  IN-0038       heliport
# 343  319166  IN-0101  small_airport
# 344   46557  IN-0034  small_airport
#
#                                           name        latitude_deg  \
# 1          Indira Gandhi International Airport             28.5665
# 2    Chhatrapati Shivaji International Airport       19.0886993408
# 3             Kempegowda International Airport             13.1979
# 4                Chennai International Airport  12.990005493164062
# 5                              Dabolim Airport       15.3808002472
# ..                                         ...                 ...
# ...

# %%
data.describe()
# Out:
#            #meta +id   #geo +lat   #geo +lon  #geo +elevation +ft  \
# count     344.000000  344.000000  344.000000           265.000000
# mean    68048.264535   22.584231   80.099894          1443.086792
# std    101193.756738    6.467373   11.073422          2442.487971
# min      3283.000000   -0.500000    0.000000             5.000000
# 25%     26458.750000   19.095750   75.757923           311.000000
# 50%     26591.000000   23.586505   78.886497           756.000000
# 75%     46551.250000   26.786850   86.473179          1685.000000
# max    331083.000000   35.500000   97.019661         22000.000000
#
#        #status +scheduled  #meta +score
# count          344.000000  3.440000e+02
# mean             0.267442  3.610759e+03
# std              0.443270  5.486840e+04
# min              0.000000  0.000000e+00
# 25%              0.000000  0.000000e+00
# 50%              0.000000  5.000000e+01
# 75%              1.000000  2.500000e+02
# max              1.000000  1.014475e+06

# %%
data.isnull().sum()
# Out:
# #meta +id                       0
# #meta +code                     0
# #loc +airport +type             0
# #loc +airport +name             0
# #geo +lat                       0
# #geo +lon                       0
# #geo +elevation +ft            79
# #region +continent +code        0
# #country +code +iso2            0
# #adm1 +code +iso                0
# #loc +municipality +name      160
# #status +scheduled              0
# #loc +airport +code +gps      109
# #loc +airport +code +iata     207
# #loc +airport +code +local    287
# #meta +url +airport           299
# #meta +url +wikipedia         193
# #meta +keywords               247
# #meta +score                    0
# #date +updated                  0
# dtype: int64

# %%
data.columns.values
# Out:
# array(['id', 'ident', 'type', 'name', 'latitude_deg', 'longitude_deg',
#        'elevation_ft', 'continent', 'iso_country', 'iso_region',
#        'municipality', 'scheduled_service', 'gps_code', 'iata_code',
#        'local_code', 'home_link', 'wikipedia_link', 'keywords', 'score',
#        'last_updated'], dtype=object)

# %%
data.groupby("type").count()
# Out:
#                  id  ident  name  latitude_deg  longitude_deg  elevation_ft  \
# type
# closed           25     25    25            25             25             2
# heliport         41     41    41            41             41            12
# large_airport    11     11    11            11             11            11
# medium_airport  108    108   108           108            108           106
# small_airport   159    159   159           159            159           134
#
#                 continent  iso_country  iso_region  municipality  \
# type
# closed                 25           25          25             9
# heliport               41           41          41            26
# large_airport          11           11          11            11
# medium_airport        108          108         108            78
# small_airport         159          159         159            60
#
#                 scheduled_service  gps_code  iata_code  local_code  home_link  \
# type
# ...

# %%
data.isnull().sum()
# Out:
# id                     0
# ident                  0
# type                   0
# name                   0
# latitude_deg           0
# longitude_deg          0
# elevation_ft          79
# continent              0
# iso_country            0
# iso_region             0
# municipality         160
# scheduled_service      0
# gps_code             109
# iata_code            207
# local_code           287
# home_link            299
# wikipedia_link       193
# keywords             247
# score                  0
# last_updated           0
# dtype: int64

# %%
data.shape
# Out:
# (344, 20)

# %%
data1 = data.groupby("type").count()

# %%
data1
# Out:
#                  id  ident  name  latitude_deg  longitude_deg  elevation_ft  \
# type
# closed           25     25    25            25             25             2
# heliport         41     41    41            41             41            12
# large_airport    11     11    11            11             11            11
# medium_airport  108    108   108           108            108           106
# small_airport   159    159   159           159            159           134
#
#                 continent  iso_country  iso_region  municipality  \
# type
# closed                 25           25          25             9
# heliport               41           41          41            26
# large_airport          11           11          11            11
# medium_airport        108          108         108            78
# small_airport         159          159         159            60
#
#                 scheduled_service  gps_code  iata_code  local_code  home_link  \
# type
# ...

# %%
data2 = data.groupby('name').count()
data2
# Out:
#                                                     id  ident  type  \
# name
# @@ Online Istikhara for Love Problem +91-982878...   1      1     1
# Aamby Valley Airport                                 1      1     1
# Abu Road Airport                                     1      1     1
# Adampur Airport                                      1      1     1
# Agartala Airport                                     1      1     1
# ...                                                 ..    ...   ...
# Yelahanka Air Force Station                          1      1     1
# Ziro Airport                                         1      1     1
# kanha                                                1      1     1
# no airport                                           1      1     1
# saharsa airstrip                                     1      1     1
#
#                                                     latitude_deg  \
# name
# @@ Online Istikhara for Love Problem +91-982878...             1
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18240/1402842581.py in <module>
# ----> 1 data2 = data2.drop(0)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4148         for axis, labels in axes.items():
# ...

# %%
data = data[(data["type"] != "closed")]

# %%
data
# Out:
#          id    ident           type  \
# 1     26555     VIDP  large_airport
# 2     26434     VABB  large_airport
# 3     35145     VOBL  large_airport
# 4     26618     VOMM  large_airport
# 5     26444     VAGO  large_airport
# ..      ...      ...            ...
# 340   46625  IN-0062  small_airport
# 341   46640  IN-0064  small_airport
# 342   46561  IN-0038       heliport
# 343  319166  IN-0101  small_airport
# 344   46557  IN-0034  small_airport
#
#                                           name        latitude_deg  \
# 1          Indira Gandhi International Airport             28.5665
# 2    Chhatrapati Shivaji International Airport       19.0886993408
# 3             Kempegowda International Airport             13.1979
# 4                Chennai International Airport  12.990005493164062
# 5                              Dabolim Airport       15.3808002472
# ..                                         ...                 ...
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 319 entries, 1 to 344
# Data columns (total 20 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 319 non-null    object
#  1   ident              319 non-null    object
#  2   type               319 non-null    object
#  3   name               319 non-null    object
#  4   latitude_deg       319 non-null    object
#  5   longitude_deg      319 non-null    object
#  6   elevation_ft       263 non-null    object
#  7   continent          319 non-null    object
#  8   iso_country        319 non-null    object
#  9   iso_region         319 non-null    object
#  10  municipality       175 non-null    object
#  11  scheduled_service  319 non-null    object
#  12  gps_code           233 non-null    object
#  13  iata_code          137 non-null    object
#  14  local_code         57 non-null     object
#  15  home_link          45 non-null     object
# ...

# %%
data.dtypes
# Out:
# id                   object
# ident                object
# type                 object
# name                 object
# latitude_deg         object
# longitude_deg        object
# elevation_ft         object
# continent            object
# iso_country          object
# iso_region           object
# municipality         object
# scheduled_service    object
# gps_code             object
# iata_code            object
# local_code           object
# home_link            object
# wikipedia_link       object
# keywords             object
# score                object
# last_updated         object
# dtype: object

# %%
data["latitude_deg"] = data["latitude_deg"].astype(str).astype(float).round()
# Out:
# <ipython-input-95-85141197caf7>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["latitude_deg"] = data["latitude_deg"].astype(str).astype(float).round()

# %%
data
# Out:
#          id    ident           type  \
# 1     26555     VIDP  large_airport
# 2     26434     VABB  large_airport
# 3     35145     VOBL  large_airport
# 4     26618     VOMM  large_airport
# 5     26444     VAGO  large_airport
# ..      ...      ...            ...
# 340   46625  IN-0062  small_airport
# 341   46640  IN-0064  small_airport
# 342   46561  IN-0038       heliport
# 343  319166  IN-0101  small_airport
# 344   46557  IN-0034  small_airport
#
#                                           name  latitude_deg  \
# 1          Indira Gandhi International Airport          29.0
# 2    Chhatrapati Shivaji International Airport          19.0
# 3             Kempegowda International Airport          13.0
# 4                Chennai International Airport          13.0
# 5                              Dabolim Airport          15.0
# ..                                         ...           ...
# 340                            Shirpur Airport          21.0
# ...

# %%
data["longitude_deg"] = data["longitude_deg"].astype(str).astype(float).round()
# Out:
# <ipython-input-97-c4523cd9b5f5>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["longitude_deg"] = data["longitude_deg"].astype(str).astype(float).round()

# %%
data
# Out:
#          id    ident           type  \
# 1     26555     VIDP  large_airport
# 2     26434     VABB  large_airport
# 3     35145     VOBL  large_airport
# 4     26618     VOMM  large_airport
# 5     26444     VAGO  large_airport
# ..      ...      ...            ...
# 340   46625  IN-0062  small_airport
# 341   46640  IN-0064  small_airport
# 342   46561  IN-0038       heliport
# 343  319166  IN-0101  small_airport
# 344   46557  IN-0034  small_airport
#
#                                           name  latitude_deg  longitude_deg  \
# 1          Indira Gandhi International Airport          29.0           77.0
# 2    Chhatrapati Shivaji International Airport          19.0           73.0
# 3             Kempegowda International Airport          13.0           78.0
# 4                Chennai International Airport          13.0           80.0
# 5                              Dabolim Airport          15.0           74.0
# ...

# %%
# !pip install pandas_datareader

# %%
# !pip install datetime

# %%
import datetime as dt
import pandas_datareader as dr

# %%
# Out:
# <ipython-input-104-97d3ea20e97e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["last_updated"] = data["last_updated"].replace("T", "")

# %%
data[['Time','Date']]= data["last_updated"].apply(lambda x:pd.Series(str(x).split("T")))

# %%
data[['wikipedia', 'search']] = data["wikipedia_link"].apply(lambda x:pd.Series(str(x).split("wiki/")))

# %%
data
# Out:
#             id        ident                 type  \
# 0    #meta +id  #meta +code  #loc +airport +type
# 1        26555         VIDP        large_airport
# 2        26434         VABB        large_airport
# 3        35145         VOBL        large_airport
# 4        26618         VOMM        large_airport
# ..         ...          ...                  ...
# 340      46625      IN-0062        small_airport
# 341      46640      IN-0064        small_airport
# 342      46561      IN-0038             heliport
# 343     319166      IN-0101        small_airport
# 344      46557      IN-0034        small_airport
#
#                                           name        latitude_deg  \
# 0                          #loc +airport +name           #geo +lat
# 1          Indira Gandhi International Airport             28.5665
# 2    Chhatrapati Shivaji International Airport       19.0886993408
# 3             Kempegowda International Airport             13.1979
# ...
